# %% [markdown]
# # Primordial Earth (HERMES tutorial)
# There are a wide variety of problems in solar system astronomy requiring accurate integration of N-bodies undergoing close encounters and collisions. Standard choices such as the Wisdom-Holman integrator are not sufficient for these problems, and one must instead turn to more exotic algorithms.
#
# In this example we investigate the primordial Earth embedded in a disk of planetesimals, integrating it for a short period of time using the HERMES integrator. HERMES is a hybrid integration scheme which combines the WHFAST and IAS15 algorithms for the optimal balance between speed and accuracy.

# %%
import rebound
import numpy as np

# %% [markdown]
# First let's choose the basic properties required for the HERMES integrator. In particular, we are:
# * Setting planetesimals to *passive* mode, which means they can influence other massive bodies but not passive ones.
# * Merging collisions according to conservation of momentum
# * Removing particles that leave our pre-defined box.
# * Tracking the energy lost due to ejections or collisions.
#
# Other choices are certainly possible.

# %%
sim = rebound.Simulation()

#integrator options
sim.integrator = "hybarid"
sim.ri_hybarid.switch_radius = 3.
sim.ri_hybarid.CE_radius = 20.
sim.dt = 0.005
sim.testparticle_type = 1

#collision and boundary options
sim.collision = "direct"
sim.collision_resolve = "merge"
sim.boundary = "open"
boxsize = 3.
sim.configure_box(boxsize)
sim.collisions_track_dE = 1

# %% [markdown]
# Now that the setup is complete, it's time to add some bodies! When using the HERMES integrator it's always important to add the massive bodies first and passive bodies later. The "sim.N_active" variable distinguishes massive bodies from passive/test bodies.

# %%
sim.add(m=1.)
sim.add(m=3e-6,r=5e-5,a=1,e=0.01)
sim.N_active = sim.N

# %% [markdown]
# Now, let's create our planetesimal disk. First we need to make use of three different distribution functions - powerlaw, uniform and rayleigh.

# %%
def rand_powerlaw(slope, min_v, max_v):
    y = np.random.uniform()
    pow_max = pow(max_v, slope+1.)
    pow_min = pow(min_v, slope+1.)
    return pow((pow_max-pow_min)*y + pow_min, 1./(slope+1.))

def rand_uniform(minimum, maximum):
    return np.random.uniform()*(maximum-minimum)+minimum

def rand_rayleigh(sigma):
    return sigma*np.sqrt(-2*np.log(np.random.uniform()))

# %% [markdown]
# Next, let's set up the basic properties of our planetesimal disk. For this simple example we are assuming that all planetesimals have the same mass and radius. Other, more complicated choices are certainly possible.

# %%
N_pl = 50
Mtot_disk = 10*sim.particles[1].m
m_pl = Mtot_disk / float(N_pl)
r_pl = 2e-5
powerlaw = 0
disk_min_a = 0.95
disk_max_a = 1.05
rayleigh_sigma = 0.01

# %% [markdown]
# Now let's add our planetesimals to the simulation!

# %%
while sim.N < (N_pl + sim.N_active):
    a = rand_powerlaw(powerlaw, disk_min_a, disk_max_a)
    e = rand_rayleigh(rayleigh_sigma)
    inc = rand_rayleigh(0.5*rayleigh_sigma)
    Omega = rand_uniform(0,2*np.pi)
    omega = rand_uniform(0,2*np.pi)
    f = rand_uniform(0,2*np.pi)
    sim.add(m=m_pl, r=r_pl, a=a, e=e, inc=inc, Omega=Omega, omega=omega, f=f)

# %% [markdown]
# Finally, since the integrator primarily uses the WHFAST algorithm we need to move to the COM frame. In addition, it is always good practice to monitor the change in energy over the course of a simulation, which requires us to calculate it before and after the simulation.

# %%
sim.move_to_com()
E0 = sim.calculate_energy()

# %% [markdown]
# We can visualize our setup using rebound.OrbitPlot

# %%
# %matplotlib inline
fig = rebound.OrbitPlot(sim, trails=True)

# %% [markdown]
# Finally, let's simulate our system for 100 years, and check that our final relative energy error is small.

# %%
sim.integrate(100)
dE = abs((sim.calculate_energy() - E0)/E0)
print dE
# Out:
# 5.1800729217e-10

# %% [markdown]
# ## Tips and Tricks for using HERMES
# 1. Choosing $dt$ - There is an intimiate balance between the hybrid switch radius ($HSR$) and the time step ($dt$). $HSR$ defines the close encounter region inside of which the IAS15 algorithm takes over, and $dt$ controls how far a particle can travel between successive close encounter checks. If these values are incorrectly chosen the integrator will certainly still run, but either your energy error will be too large or the integration will take much longer than it needs to. As a rough rule of thumb you should aim for: $dt \sim \frac{HSR*r_{hill,cmb}}{dv_{max}}$, where $dv_{max}$ is the max relative velocity between your planet and planetesimal over the course of a simulation and $r_{hill,cmb}$ is the combined hill radius of your planet and planetesimal (can be approximated as just the planet's hill radius).
#
# 2. Choosing $HSR$ - This choice depends on a variety of reasons specific to your problem. A larger $HSR$ means a more accurate integration, but the simulation will also take longer. This becomes especially apparent when your planetesimal disk contains many (>1000) planetesimals. As another rule of thumb, the hill sphere defines the region inside which the planet's gravity is stronger than the star's. Because of this, it never makes sense to set $HSR$ to less than 1 ($HSR$ is in units of hill radius), since we always want to safely switch to the IAS15 *before* a close encounter happens.
